# %%
from selenium import webdriver
import time

# 创建浏览器对象，该操作会自动帮我们打开Google浏览器窗口
browser = webdriver.Chrome()

# 调用浏览器对象，向服务器发送请求。该操作会打开Google浏览器，并跳转到“百度”首页
browser.get("https://www.baidu.com/")

# 刷新浏览器
browser.refresh()

# 最大化窗口
browser.maximize_window()

# 定位“抗击肺炎”链接内容
element = browser.find_element_by_link_text("抗击肺炎")
# 为了更好的展示这个效果，我们等待3秒钟
time.sleep(3)
# 点击上述链接
element.click()

# %%
from selenium import webdriver
import time

def search_product():
    pass

def get_data():
    print("hello, 丽丽姑娘")
    pass

def main():
    pass

if __name__ == '__main__':
    main()
    print("hello, 黄伟")
# Out:
# hello, 黄伟

# %% [markdown]
# ### 一个简单的小测试

# %%
from selenium import webdriver
import time

# 搜索商品
def search_product(key_word):
    # 定位输入框
    browser.find_element_by_id("q").send_keys(key_word)
    # 定义点击按钮，并点击
    browser.find_element_by_class_name('btn-search').click()
    # 最大化窗口：为了方便我们扫码
    browser.maximize_window()
    # 等待15秒，给足时间我们扫码
    time.sleep(15)

# 获取数据
def get_data():
    pass

def main():
    browser.get('https://www.taobao.com/')
    search_product(key_word)

if __name__ == '__main__':
    key_word = input("请输入你要搜索的商品：")
    browser = webdriver.Chrome()
    main()
# Out:
# 请输入你要搜索的商品：口红

# %% [markdown]
# ### 翻页怎么处理呢？

# %%
import re

str = "共100页"
x = re.findall("\d+",str)
print(x)

y = re.findall("\d+",str)[0]
print(y)
print(type(y))
# Out:
# ['100']
# 100
# <class 'str'>

# %%
from selenium import webdriver
import time

# 搜索商品，获取商品页码
def search_product(key_word):
    # 定位输入框
    browser.find_element_by_id("q").send_keys(key_word)
    # 定义点击按钮，并点击
    browser.find_element_by_class_name('btn-search').click()
    # 最大化窗口：为了方便我们扫码
    browser.maximize_window()
    # 等待15秒，给足时间我们扫码
    time.sleep(15)
    # 定位这个“页码”，获取“共100页这个文本”
    page_info = browser.find_element_by_xpath('//div[@class="total"]').text
    # 需要注意的是：findall()返回的是一个列表，虽然此时只有一个元素它也是一个列表。
    page = re.findall("(\d+)",page_info)[0]
    return page

# 获取数据
def get_data():
    pass

def main():
    browser.get('https://www.taobao.com/')
    page = search_product(key_word)
    print(type(page))
    print(page)

if __name__ == '__main__':
    key_word = input("请输入你要搜索的商品：")
    browser = webdriver.Chrome()
    main()
# Out:
# 请输入你要搜索的商品：口红
# <class 'str'>
# 100

# %% [markdown]
# ### 定位商品
# ### 价格，旗舰店，发货地，付款人数，参数信息，主页图片

# %%
from selenium import webdriver
import time

# 搜索商品，获取商品页码
def search_product(key_word):
    # 定位输入框
    browser.find_element_by_id("q").send_keys(key_word)
    # 定义点击按钮，并点击
    browser.find_element_by_class_name('btn-search').click()
    # 最大化窗口：为了方便我们扫码
    browser.maximize_window()
    # 等待15秒，给足时间我们扫码
    time.sleep(15)
    # 定位这个“页码”，获取“共100页这个文本”
    page_info = browser.find_element_by_xpath('//div[@class="total"]').text
    # 需要注意的是：findall()返回的是一个列表，虽然此时只有一个元素它也是一个列表。
    page = re.findall("(\d+)",page_info)[0]
    return page

# 获取数据
def get_data():
    # 通过页面分析发现：所有的信息都在items节点下
    items = browser.find_elements_by_xpath('//div[@class="items"]/div[@class="item J_MouserOnverReq  "]')
    for item in items:
        # 参数信息
        pro_desc = item.find_element_by_xpath('.//div[@class="row row-2 title"]/a').text
        # 价格
        pro_price = item.find_element_by_xpath('.//strong').text
        # 付款人数
        buy_num = item.find_element_by_xpath('.//div[@class="deal-cnt"]').text
        # 旗舰店
        shop = item.find_element_by_xpath('.//div[@class="shop"]/a').text
        # 发货地
        address = item.find_element_by_xpath('.//div[@class="location"]').text
        print(pro_desc, pro_price, buy_num, shop, address)

def main():
    browser.get('https://www.taobao.com/')
    page = search_product(key_word)
    print(page)
    get_data()

if __name__ == '__main__':
    key_word = input("请输入你要搜索的商品：")
    browser = webdriver.Chrome()
    main()
# Out:
# 请输入你要搜索的商品：口红
# 100
# 【屈臣氏】GLO＆RAY光芮唇爱唇膏原色/微光滋润显色不易脱色口红 151.00 1人付款 屈臣氏官方旗舰店 江苏 苏州
# 爱茉莉Hera/赫妍魅感小辣椒丰盈哑光口红 自然显色雾感丝滑唇膏 230.00 41人付款 爱茉莉官方海外旗舰店 韩国
# 李佳琦推荐空气唇釉丝绒哑光雾面口红滋润保湿唇彩小众女学生平价 14.90 331人付款 欧伊俪旗舰店 广东 深圳
# 李佳琦推荐变色唇膏保湿滋润女小众口红不掉色不沾杯补水大牌正品 9.90 244人付款 欧伊俪旗舰店 广东 广州
# 阿玛尼口红405番茄红唇釉红黑管哑光200 415 500 501 524 400礼盒 189.00 3616人付款 mysnku韩式 广东 深圳
# 正品Chanel香奈儿口红滋润保湿丝绒炫亮魅力唇膏43 46 57 58 152 190.00 3754人付款 b百分百d 上海
# 正品Chanel/香奈儿口红炫亮唇膏3.5g丝绒保湿滋润 42#43#136#色号 190.00 2579人付款 七梵米亚 上海
# Chanel香奈儿新品山茶花限量口红丝绒黑金魅力唇膏357/837/857 208.00 2246人付款 m_少根筋姐姐 上海
# 正品Chanel/香奈儿口红丝绒炫亮保湿魅力唇膏42#43#56#57#58#172# 190.00 2484人付款 时尚潮流前线0008 上海
# Chanel/香奈儿口红正品58号色丝绒炫亮魅力唇膏42#43#56#57#172# 190.00 1306人付款 杨鹏飞网银yl 上海
# Armani/阿玛尼红管唇釉丝绒哑光口红番茄色405/206/205红棕色 310.00 6.0万+人付款 阿玛尼美妆官方旗舰店 江苏 苏州
# YSL圣罗兰细管口红小金条哑光复古红21干枯玫瑰12 335.00 2.0万+人付款 ysl圣罗兰美妆官方旗舰店 江苏 苏州
# 现货CL口红萝卜丁女王权杖持久滋润黑管唇膏001金管限量版 正品 598.00 1404人付款 梦花流水 上海
# Dior迪奥口红送礼999哑光滋润正红740/888专柜大牌唇膏礼盒装正品 163.00 2062人付款 sd1554040 广东 深圳
# 正品Chanel/香奈儿口红丝绒保湿炫亮魅力唇膏42#43#56#57#58#172# 190.00 1078人付款 mengwenxue 上海
# 迪可迪奥口红唇膏滋润999官网限量版520礼盒套装哑光888正品大牌 168.00 5500+人付款 懒人潮阁 上海
# Christian Louboutin女王权杖 全色cl萝卜丁口红 官方旗舰店 正品 880.00 4427人付款 christianlouboutin美妆官方旗舰店
# 正品Chanel/香奈儿口红炫亮魅力唇膏3.5g丝绒保湿滋润 43#58#136# 188.00 1589人付款 一津源童鞋 上海
# Dior迪奥口红999哑光520正品740经典正红888限量版送礼套装礼盒装 349.00 1203人付款 tingyuelanfeng 广东 深圳
# 官网正品大牌萝卜丁CL口红女王权杖001M黑管女王节限定礼盒套装 598.00 1056人付款 星光贸易001 上海
# Chanel香奈儿口红炫亮魅力黑管柔雾哑光丝绒唇膏43 58 99 112 116 190.00 3234人付款 美绮可依 广东 深圳
# 阿玛尼唇釉302 401 201 400 402 206口红大牌正品红管405番茄红 200.00 781人付款 sd1554040 广东 深圳
# 【官方正品】CHANEL 香奈儿炫亮魅力唇膏丝绒系列 哑光口红58 330.00  chanel香奈儿官方旗舰店 浙江 杭州
# 【官方正品】CHANEL 香奈儿炫亮魅力柔雾唇膏口红#116#132 #130 330.00  chanel香奈儿官方旗舰店 浙江 杭州
# 【官方正品】MAC/魅可尤雾弹哑光唇膏口红大牌正品923 奶茶色 170.00 10万+人付款 mac魅可官方旗舰店 上海
# Hermes爱马仕口红缎光滋润21/40/66/75哑光拼色唇膏48/64/68/85 506.00 606人付款 等待yry 广东 深圳
# 正品Hermes/爱马仕口红缎光滋润21/40/66/75哑光64/68/85拼色唇膏 506.00 645人付款 id世纪汇置 广东 深圳
# Dior迪奥口红送礼999哑光滋润正红740/888唇膏礼盒装专柜大牌正品 155.00 3355人付款 永远玩美 广东 深圳
# 【官方正品】GIVENCHY纪梵希小羊皮口红半哑光唇膏333 306 正品 345.00 1.5万+人付款 givenchy纪梵希官方旗舰店 上海
# 花西子雕花口红/浮雕唇膏女半哑光正红烂番茄色中国风杜鹃定制款 129.00 6.0万+人付款 花西子旗舰店 浙江 杭州
# chanel香奈儿口红58号106限量版正品116套装70礼盒装857山茶花627 228.00 1534人付款 conandanube 广东 深圳
# 【官方正品】MAC/魅可大理石限定口红大牌正品唇膏脏橘色 小辣椒 170.00 9.0万+人付款 mac魅可官方旗舰店 上海
# 正品Chanel/香奈儿口红新限量山茶花黑金魅力唇膏817#807#837#857 208.00 1206人付款 一津源童鞋 上海
# 胡萝卜素变色唇膏女保湿滋润补水小众口红不掉色不沾杯润唇膏唇彩 69.00 2.0万+人付款 sckiquen旗舰店 广东 广州
# 水木萃白口红雨衣不掉色不沾杯 持久防水不脱色定妆李佳琪琦推荐1 49.90 6500+人付款 水木萃白旗舰店 广东 广州
# 正品Christian Louboutin女王权杖CL口红萝卜丁黑管001M刻字礼盒 558.00 603人付款 金品数码城 广东 深圳
# 现货Hermes爱马仕口红缎光滋润21/64/66/75哑光唇膏拼色64/68/85 506.00 991人付款 suauw 上海
# 纪梵希限量口红333 325n37小羊皮306 307正品大牌n11红丝绒礼盒 179.00 4792人付款 法兰释企业店铺 上海
# 法国Christian Louboutin进口萝卜丁女王权杖口红情人礼物送女友 835.00 225人付款 天猫国际进口超市 浙江 杭州
# 阿玛尼哑光唇釉番茄红管405 415 206大牌正品黑管口红302 402 500 178.00 194人付款 tiandi445 上海
# Chanel口红香奈儿58号56丝绒唇膏99正品女169限量版套装礼盒42 43 218.00 1352人付款 天天宝贝母婴用品 上海
# Chanel香奈儿口红丝绒炫亮哑光42 43 46 56 57 58 96 99 136唇膏 168.00 561人付款 百姓东东8 上海
# YSL圣罗兰方管口红 保湿滋润柿红官方正品 320.00 8000+人付款 ysl圣罗兰美妆官方旗舰店 江苏 苏州
# 雪玲妃口红雨衣不掉色不沾杯不脱色持久正品防水唇釉防掉色神器 49.90 4.5万+人付款 雪玲妃洛莎曼专卖店 上海
# 【官方正品】GIVENCHY纪梵希美炸红丝绒口红唇膏女 N37哑光唇膏 345.00 3.0万+人付款 givenchy纪梵希官方旗舰店 上海
# 正品迪奥dior口红999哑光红管大牌641枫叶红888女740/777限量520 158.00 3088人付款 霹雳小文哥 山东 青岛
# 台湾heme喜蜜经典柔雾口红经典肉桂奶茶色复古枣红色雾面哑光唇膏 70.00 3人付款 t_1500655522761_0909 浙江 宁波

# %% [markdown]
# ### 第一次保存数据

# %%
from selenium import webdriver
import time
import csv

# 搜索商品，获取商品页码
def search_product(key_word):
    # 定位输入框
    browser.find_element_by_id("q").send_keys(key_word)
    # 定义点击按钮，并点击
    browser.find_element_by_class_name('btn-search').click()
    # 最大化窗口：为了方便我们扫码
    browser.maximize_window()
    # 等待15秒，给足时间我们扫码
    time.sleep(15)
    # 定位这个“页码”，获取“共100页这个文本”
    page_info = browser.find_element_by_xpath('//div[@class="total"]').text
    # 需要注意的是：findall()返回的是一个列表，虽然此时只有一个元素它也是一个列表。
    page = re.findall("(\d+)",page_info)[0]
    return page

# 获取数据
def get_data():
    # 通过页面分析发现：所有的信息都在items节点下
    items = browser.find_elements_by_xpath('//div[@class="items"]/div[@class="item J_MouserOnverReq  "]')
    for item in items:
        # 参数信息
        pro_desc = item.find_element_by_xpath('.//div[@class="row row-2 title"]/a').text
        # 价格
        pro_price = item.find_element_by_xpath('.//strong').text
        # 付款人数
        buy_num = item.find_element_by_xpath('.//div[@class="deal-cnt"]').text
        # 旗舰店
        shop = item.find_element_by_xpath('.//div[@class="shop"]/a').text
        # 发货地
        address = item.find_element_by_xpath('.//div[@class="location"]').text
        #print(pro_desc, pro_price, buy_num, shop, address)
        with open('{}.csv'.format(key_word), mode='a', newline='', encoding='utf-8-sig') as f:
            csv_writer = csv.writer(f, delimiter=',')
            csv_writer.writerow([pro_desc, pro_price, buy_num, shop, address])

def main():
    browser.get('https://www.taobao.com/')
    page = search_product(key_word)
    print(page)
    get_data()

if __name__ == '__main__':
    key_word = input("请输入你要搜索的商品：")
    browser = webdriver.Chrome()
    main()
# Out:
# 请输入你要搜索的商品：口红
# 100

# %% [markdown]
# ### url的拼接，进行翻页操作
# ### https://s.taobao.com/search?q=%E7%AC%94%E8%AE%B0%E6%9C%AC%E7%94%B5%E8%84%91&s=44

# %%
from selenium import webdriver
import time
import csv

# 搜索商品，获取商品页码
def search_product(key_word):
    # 定位输入框
    browser.find_element_by_id("q").send_keys(key_word)
    # 定义点击按钮，并点击
    browser.find_element_by_class_name('btn-search').click()
    # 最大化窗口：为了方便我们扫码
    browser.maximize_window()
    # 等待15秒，给足时间我们扫码
    time.sleep(15)
    # 定位这个“页码”，获取“共100页这个文本”
    page_info = browser.find_element_by_xpath('//div[@class="total"]').text
    # 需要注意的是：findall()返回的是一个列表，虽然此时只有一个元素它也是一个列表。
    page = re.findall("(\d+)",page_info)[0]
    return page

# 获取数据
def get_data():
    # 通过页面分析发现：所有的信息都在items节点下
    items = browser.find_elements_by_xpath('//div[@class="items"]/div[@class="item J_MouserOnverReq  "]')
    for item in items:
        # 参数信息
        pro_desc = item.find_element_by_xpath('.//div[@class="row row-2 title"]/a').text
        # 价格
        pro_price = item.find_element_by_xpath('.//strong').text
        # 付款人数
        buy_num = item.find_element_by_xpath('.//div[@class="deal-cnt"]').text
        # 旗舰店
        shop = item.find_element_by_xpath('.//div[@class="shop"]/a').text
        # 发货地
        address = item.find_element_by_xpath('.//div[@class="location"]').text
        #print(pro_desc, pro_price, buy_num, shop, address)
        with open('{}.csv'.format(key_word), mode='a', newline='', encoding='utf-8-sig') as f:
            csv_writer = csv.writer(f, delimiter=',')
            csv_writer.writerow([pro_desc, pro_price, buy_num, shop, address])

def main():
    browser.get('https://www.taobao.com/')
    page = search_product(key_word)
    print(page)
    get_data()
    page_num = 1
    while int(page) != page_num:
        print("*" * 100)
        print("正在爬取第{}页".format(page_num + 1))
        browser.get('https://s.taobao.com/search?q={}&s={}'.format(key_word, page_num*44))
        browser.implicitly_wait(15)
        get_data()
        page_num += 1
    print("数据爬取完毕！")

if __name__ == '__main__':
    key_word = input("请输入你要搜索的商品：")
    browser = webdriver.Chrome()
    main()
# Out:
# 请输入你要搜索的商品：口红
# 100
# ****************************************************************************************************
# 正在爬取第2页
# ****************************************************************************************************
# 正在爬取第3页
# ****************************************************************************************************
# 正在爬取第4页
# ****************************************************************************************************
# 正在爬取第5页
# ****************************************************************************************************
# 正在爬取第6页
# ****************************************************************************************************
# 正在爬取第7页
# ****************************************************************************************************
# 正在爬取第8页
# ****************************************************************************************************
# 正在爬取第9页
# ****************************************************************************************************
# 正在爬取第10页
# ****************************************************************************************************
# 正在爬取第11页
# ****************************************************************************************************
# 正在爬取第12页
# ****************************************************************************************************
# 正在爬取第13页
# ****************************************************************************************************
# 正在爬取第14页
# ****************************************************************************************************
# 正在爬取第15页
# ****************************************************************************************************
# 正在爬取第16页
# ****************************************************************************************************
# 正在爬取第17页
# ****************************************************************************************************
# 正在爬取第18页
# ****************************************************************************************************
# 正在爬取第19页
# ****************************************************************************************************
# 正在爬取第20页
# ****************************************************************************************************
# 正在爬取第21页
# ****************************************************************************************************
# 正在爬取第22页
# ****************************************************************************************************
# 正在爬取第23页
# ****************************************************************************************************
# 正在爬取第24页
# ****************************************************************************************************
# 正在爬取第25页
# ****************************************************************************************************
# 正在爬取第26页
# ****************************************************************************************************
# 正在爬取第27页
# ****************************************************************************************************
# 正在爬取第28页
# ****************************************************************************************************
# 正在爬取第29页
# ****************************************************************************************************
# 正在爬取第30页
# ****************************************************************************************************
# 正在爬取第31页
# ****************************************************************************************************
# 正在爬取第32页
# ****************************************************************************************************
# 正在爬取第33页
# ****************************************************************************************************
# 正在爬取第34页
# ****************************************************************************************************
# 正在爬取第35页
# ****************************************************************************************************
# 正在爬取第36页
# ****************************************************************************************************
# 正在爬取第37页
# ****************************************************************************************************
# 正在爬取第38页
# ****************************************************************************************************
# 正在爬取第39页
# ****************************************************************************************************
# 正在爬取第40页
# ****************************************************************************************************
# 正在爬取第41页
# ****************************************************************************************************
# 正在爬取第42页
# ****************************************************************************************************
# 正在爬取第43页
# ****************************************************************************************************
# 正在爬取第44页
# ****************************************************************************************************
# 正在爬取第45页
# ****************************************************************************************************
# 正在爬取第46页
# ****************************************************************************************************
# 正在爬取第47页
# ****************************************************************************************************
# 正在爬取第48页
# ****************************************************************************************************
# 正在爬取第49页
# ****************************************************************************************************
# 正在爬取第50页
# ****************************************************************************************************
# 正在爬取第51页
# ****************************************************************************************************
# 正在爬取第52页
# ****************************************************************************************************
# 正在爬取第53页
# ****************************************************************************************************
# 正在爬取第54页
# ****************************************************************************************************
# 正在爬取第55页
# ****************************************************************************************************
# 正在爬取第56页
# ****************************************************************************************************
# 正在爬取第57页
# ****************************************************************************************************
# 正在爬取第58页
# ****************************************************************************************************
# 正在爬取第59页
# ****************************************************************************************************
# 正在爬取第60页
# ****************************************************************************************************
# 正在爬取第61页
# ****************************************************************************************************
# 正在爬取第62页
# ****************************************************************************************************
# 正在爬取第63页
# ****************************************************************************************************
# 正在爬取第64页
# ****************************************************************************************************
# 正在爬取第65页
# ****************************************************************************************************
# 正在爬取第66页
# ****************************************************************************************************
# 正在爬取第67页
# ****************************************************************************************************
# 正在爬取第68页
# ****************************************************************************************************
# 正在爬取第69页
# ****************************************************************************************************
# 正在爬取第70页
# ****************************************************************************************************
# 正在爬取第71页
# ****************************************************************************************************
# 正在爬取第72页
# ****************************************************************************************************
# 正在爬取第73页
# ****************************************************************************************************
# 正在爬取第74页
# ****************************************************************************************************
# 正在爬取第75页
# ****************************************************************************************************
# 正在爬取第76页
# ****************************************************************************************************
# 正在爬取第77页
# ****************************************************************************************************
# 正在爬取第78页
# ****************************************************************************************************
# 正在爬取第79页
# ****************************************************************************************************
# 正在爬取第80页
# ****************************************************************************************************
# 正在爬取第81页
# ****************************************************************************************************
# 正在爬取第82页
# ****************************************************************************************************
# 正在爬取第83页
# ****************************************************************************************************
# 正在爬取第84页
# ****************************************************************************************************
# 正在爬取第85页
# ****************************************************************************************************
# 正在爬取第86页
# ****************************************************************************************************
# 正在爬取第87页
# ****************************************************************************************************
# 正在爬取第88页
# ****************************************************************************************************
# 正在爬取第89页
# ****************************************************************************************************
# 正在爬取第90页
# ****************************************************************************************************
# 正在爬取第91页
# ****************************************************************************************************
# 正在爬取第92页
# ****************************************************************************************************
# 正在爬取第93页
# ****************************************************************************************************
# 正在爬取第94页
# ****************************************************************************************************
# 正在爬取第95页
# ****************************************************************************************************
# 正在爬取第96页
# ****************************************************************************************************
# 正在爬取第97页
# ****************************************************************************************************
# 正在爬取第98页
# ****************************************************************************************************
# 正在爬取第99页
# ****************************************************************************************************
# 正在爬取第100页
# 数据爬取完毕！
